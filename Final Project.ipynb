# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from ast import literal_eval
movies_df = pd.read_csv("moviez.csv")
ratings_df = pd.read_csv("ratingz.csv")
from tkinter import *
from ttkwidgets.autocomplete import AutocompleteCombobox


movies = movies_df['title'].tolist()

master = Tk()
master.title('RECOMMEDER')
master.geometry('1920x1080')
filename = PhotoImage(file = "C:\\Users\\SIRAJ\\Desktop\\rsp\\movie-recommendation-system-code\\zzz.png")
background_label = Label(master, image=filename)
background_label.place(x=0, y=0, relwidth=1, relheight=1)

label = Label(
    master, 
    bg='white',
    font = ('Times',21),
    text='Type Your Fav Movie:'
    )
label.place(x=600,y=25)

entry = AutocompleteCombobox(
    master, 
    width=30, 
    font=('Times', 18),
    completevalues=movies
    )
entry.place(x=540,y=75)



def recommend(): 
    mov = entry.get()
    def get_id_from_title(title):
        return movies_df[movies_df.title == title]["movie_id"].values[0]
    m_id = get_id_from_title(mov)
    m_id = m_id -1
    def return_cosine_similarity(ratings_df, title):
        index = movies_df[movies_df.title == title].movie_id.values[0]-1 # Movie id starts from 1 in the dataset
        movie_row = ratings_df[index, :]
        magnitude = np.sqrt(np.einsum('ij, ij -> i', ratings_df, ratings_df))
        similarity = np.dot(movie_row, ratings_df.T) / (magnitude[index] * magnitude)
        return similarity
    ratings_mat = np.ndarray(shape=(np.max(ratings_df.movie_id.values), np.max(ratings_df.user_id.values)),dtype=np.uint8)
    ratings_mat[ratings_df.movie_id.values-1, ratings_df.user_id.values-1] = ratings_df.rating.values
    normalised_mat = ratings_mat - np.asarray([(np.mean(ratings_mat, 1))]).T
    A = normalised_mat.T / np.sqrt(ratings_mat.shape[0] - 1)
    U, S, V = np.linalg.svd(A)
    sd = V.T[:, :30]
    title = mov 
    scores = return_cosine_similarity(sd, title)
    similar_movies2 = list(enumerate(scores))
    df=pd.DataFrame(similar_movies2)
    df.columns = ['movie_id', 'sim']
    df['movie_id']=df['movie_id']+1
    df1=pd.merge(ratings_df,df, on="movie_id")
    df1["score"]=df1.rating*df1.sim
    df2=df1.groupby("movie_id")["score"].agg([np.mean])
    df3=pd.merge(movies_df,df2, on="movie_id")

    df3["index"]=df3.index
    df3['year'] = df3.title.str.extract('(\(\d\d\d\d\))',expand=False)
    df3['year'] = df3.year.str.extract('(\d{4})',expand=False)
    df3['name'] = df3.title.str.replace('(\(\d\d\d\d\))', '',regex=True)
    features=['name','genres','mean']
    for feature in features:
        df3[feature]=df3[feature].fillna('')
    def combined_features(row):
        return row['name']+"|"+row['genres']
    df3["combined_features"] = df3.apply(combined_features, axis =1)
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(df3["combined_features"])
    cosine_sim = cosine_similarity(count_matrix)
    movie_user_likes = mov
    def get_index_from_title(title):
        return df3[df3.title == title]["index"].values[0]
    movie_index = get_index_from_title(movie_user_likes)
    def get_imdb_from_title(title):
        return df3[df3.title == title]["imdbId"].values[0]
    imdb = get_imdb_from_title(movie_user_likes)
    def get_tmdb_from_title(title):
        return df3[df3.title == title]["tmdbId"].values[0]
    tmdb = get_tmdb_from_title(movie_user_likes)
    tmdb=tmdb.astype('str')
    similar_movies1 = list(cosine_sim[movie_index])
    def ns(n1,n2):
        v=(2*min(n1,n2)/(n1+n2))
        return v
    nl=[]
    for i in range(0,9053):
        val=ns(df3["mean"].iloc[m_id],df3["mean"].iloc[i])
        nl.append(val)
    list((nl))
    from operator import add
    hsim = list(map(add, similar_movies1, nl))
    hsim2 = [x/2 for x in hsim]
    hsim3 = list(enumerate(hsim2))
    del hsim3[m_id]
    df4=pd.DataFrame(hsim3)
    df4.columns = ['movie_id', 'sim']
    df4['movie_id']=df4['movie_id']+1
    df5=pd.merge(df3,df4, on="movie_id")
    df6=df5.sort_values('sim',ascending=False)
    df7=df6[['title','imdbId','tmdbId']]
    df7=df7.head(10)
    df7['imdbId'] = df7['imdbId'].astype('str')
    df7['tmdbId'] = df7['tmdbId'].astype('str')

    title=df7['title'].tolist()
    imdbId=df7['imdbId'].tolist()
    tmdbId=df7['tmdbId'].tolist()
    
    
    
    global la,lb,lc,ld,le,lf,lg,l1,l2,l3,l4,l5,l6,l7,l8,l9,l10
    global m0,m1,m2,m3,m4,m5,m6,m7,m8,m9,m10
    global ib0,ib1,ib2,ib3,ib4,ib5,ib6,ib7,ib8,ib9,ib10
    global tb0,tb1,tb2,tb3,tb4,tb5,tb6,tb7,tb8,tb9,tb10
    global btni,btnt
    
    la = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    la.config(bg="white")
    la.grid(row = 0, column = 1, padx=25, pady = 5)
    lb = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    lb.config(bg="white")
    lb.grid(row = 1, column = 1, padx=25, pady = 5)
    lc = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    lc.config(bg="white")
    lc.grid(row = 2, column = 1, padx=25, pady = 5)
    ld = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    ld.config(bg="white")
    ld.grid(row = 3, column = 1, padx=25, pady = 5)
    le = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    le.config(bg="white")
    le.grid(row = 4, column = 1, padx=25, pady = 5)
    lf = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    lf.config(bg="white")
    lf.grid(row = 5, column = 1, padx=25, pady = 5)
    lg = Label(master, text = "", font = 'bold', borderwidth=0, highlightthickness=0)
    lg.config(bg="white")
    lg.grid(row = 6, column = 1, padx=25, pady = 5)
    l1 = Label(master, text = "#1", font = 'bold',width=3)
    l1.grid(row = 7, column = 2, padx=25, pady = 5)
    l2 = Label(master, text = "#2", font = 'bold',width=3)
    l2.grid(row = 8, column = 2, padx=25, pady = 5)
    l3 = Label(master, text = "#3", font = 'bold',width=3)
    l3.grid(row = 9, column = 2, padx=25, pady = 5)
    l4 = Label(master, text = "#4", font = 'bold',width=3)
    l4.grid(row = 10, column = 2, padx=25, pady = 5)
    l5 = Label(master, text = "#5", font = 'bold',width=3)
    l5.grid(row = 11, column = 2, padx=25, pady = 5)
    l6 = Label(master, text = "#6", font = 'bold',width=3)
    l6.grid(row = 12, column = 2, padx=25, pady = 5)
    l7 = Label(master, text = "#7", font = 'bold',width=3)
    l7.grid(row = 13, column = 2, padx=25, pady = 5)
    l8 = Label(master, text = "#8", font = 'bold',width=3)
    l8.grid(row = 14, column = 2, padx=25, pady = 5)
    l9 = Label(master, text = "#9", font = 'bold',width=3)
    l9.grid(row = 15, column = 2, padx=25, pady = 5)
    l10 = Label(master, text = "#10", font = 'bold',width=3)
    l10.grid(row = 16, column = 2, padx=25, pady = 5)
    l1.config(bg="lavender")
    l2.config(bg="lavender")
    l3.config(bg="lavender")
    l4.config(bg="lavender")
    l5.config(bg="lavender")
    l6.config(bg="lavender")
    l7.config(bg="lavender")
    l8.config(bg="lavender")
    l9.config(bg="lavender")
    l10.config(bg="lavender")
  
    m1 = Label(master, text = title[0], font = ('Times',20), width=70)
    m1.grid(row = 7, column = 3, padx=25, pady = 5)
    m2 = Label(master, text = title[1], font = ('Times',20), width=70)
    m2.grid(row = 8, column = 3, padx=25, pady = 5)
    m3 = Label(master, text = title[2], font = ('Times',20), width=70)
    m3.grid(row = 9, column = 3, padx=25, pady = 5)
    m4 = Label(master, text = title[3], font = ('Times',20), width=70)
    m4.grid(row = 10, column = 3, padx=25, pady = 5)
    m5 = Label(master, text = title[4], font = ('Times',20), width=70)
    m5.grid(row = 11, column = 3, padx=25, pady = 5)
    m6 = Label(master, text = title[5], font = ('Times',20), width=70)
    m6.grid(row = 12, column = 3, padx=25, pady = 5)
    m7 = Label(master, text = title[6], font = ('Times',20), width=70)
    m7.grid(row = 13, column = 3, padx=25, pady = 5)
    m8 = Label(master, text = title[7], font = ('Times',20), width=70)
    m8.grid(row = 14, column = 3, padx=25, pady = 5)
    m9 = Label(master, text = title[8], font = ('Times',20), width=70)
    m9.grid(row = 15, column = 3, padx=25, pady = 5)
    m10 = Label(master, text = title[9], font = ('Times',20), width=70)
    m10.grid(row = 16, column = 3, padx=25, pady = 5)
    m1.config(bg="lavender")
    m2.config(bg="lavender")
    m3.config(bg="lavender")
    m4.config(bg="lavender")
    m5.config(bg="lavender")
    m6.config(bg="lavender")
    m7.config(bg="lavender")
    m8.config(bg="lavender")
    m9.config(bg="lavender")
    m10.config(bg="lavender")
    
    
    import webbrowser
    def linki():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdb)
    def linki1():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[0])
    def linki2():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[1])
    def linki3():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[2])
    def linki4():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[3])
    def linki5():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[4])
    def linki6():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[5])
    def linki7():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[6])
    def linki8():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[7])
    def linki9():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[8])
    def linki10():
        webbrowser.open_new(r"https://www.imdb.com/title/"+imdbId[9])
    def linkt():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdb)
    def linkt1():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[0])
    def linkt2():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[1])
    def linkt3():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[2])
    def linkt4():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[3])
    def linkt5():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[4])
    def linkt6():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[5])
    def linkt7():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[6])
    def linkt8():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[7])
    def linkt9():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[8])
    def linkt10():
        webbrowser.open_new(r"https://www.themoviedb.org/movie/"+tmdbId[9])
        
    btni = Button(master, text="IMDB", bg="gold2", fg="black",command=linki)
    btni.place(x=630, y=140)
    
    btnt = Button(master, text="TMDB", bg="SkyBlue2", fg="black",command=linkt)
    btnt.place(x=800, y=140)
    
    ib1 = Button(master, text = "IMDB",width=7,command=linki1)
    ib1.grid(row = 7, column = 4, padx=25, pady = 5)
    ib2 = Button(master, text = "IMDB",width=7,command=linki2)
    ib2.grid(row = 8, column = 4, padx=25, pady = 5)
    ib3 = Button(master, text = "IMDB",width=7,command=linki3)
    ib3.grid(row = 9, column = 4, padx=25, pady = 5)
    ib4 = Button(master, text = "IMDB",width=7,command=linki4)
    ib4.grid(row = 10, column = 4, padx=25, pady = 5)
    ib5 = Button(master, text = "IMDB",width=7,command=linki5)
    ib5.grid(row = 11, column = 4, padx=25, pady = 5)
    ib6 = Button(master, text = "IMDB",width=7,command=linki6)
    ib6.grid(row = 12, column = 4, padx=25, pady = 5)
    ib7 = Button(master, text = "IMDB",width=7,command=linki7)
    ib7.grid(row = 13, column = 4, padx=25, pady = 5)
    ib8 = Button(master, text = "IMDB",width=7,command=linki8)
    ib8.grid(row = 14, column = 4, padx=25, pady = 5)
    ib9 = Button(master, text = "IMDB",width=7,command=linki9)
    ib9.grid(row = 15, column = 4, padx=25, pady = 5)
    ib10 = Button(master, text = "IMDB",width=7,command=linki10)
    ib10.grid(row = 16, column = 4, padx=25, pady = 5)
    ib1.config(bg="gold2")
    ib2.config(bg="gold2")
    ib3.config(bg="gold2")
    ib4.config(bg="gold2")
    ib5.config(bg="gold2")
    ib6.config(bg="gold2")
    ib7.config(bg="gold2")
    ib8.config(bg="gold2")
    ib9.config(bg="gold2")
    ib10.config(bg="gold2")

    tb1 = Button(master, text = "TMDB",width=7,command=linkt1)
    tb1.grid(row = 7, column = 5, padx=25, pady = 5)
    tb2 = Button(master, text = "TMDB",width=7,command=linkt2)
    tb2.grid(row = 8, column = 5, padx=25, pady = 5)
    tb3 = Button(master, text = "TMDB",width=7,command=linkt3)
    tb3.grid(row = 9, column = 5, padx=25, pady = 5)
    tb4 = Button(master, text = "TMDB",width=7,command=linkt4)
    tb4.grid(row = 10, column = 5, padx=25, pady = 5)
    tb5 = Button(master, text = "TMDB",width=7,command=linkt5)
    tb5.grid(row = 11, column = 5, padx=25, pady = 5)
    tb6 = Button(master, text = "TMDB",width=7,command=linkt6)
    tb6.grid(row = 12, column = 5, padx=25, pady = 5)
    tb7 = Button(master, text = "TMDB",width=7,command=linkt7)
    tb7.grid(row = 13, column = 5, padx=25, pady = 5)
    tb8 = Button(master, text = "TMDB",width=7,command=linkt8)
    tb8.grid(row = 14, column = 5, padx=25, pady = 5)
    tb9 = Button(master, text = "TMDB",width=7,command=linkt9)
    tb9.grid(row = 15, column = 5, padx=25, pady = 5)
    tb10 = Button(master, text = "TMDB",width=7,command=linkt10)
    tb10.grid(row = 16, column = 5, padx=25, pady = 5)
    tb1.config(bg="SkyBlue2")
    tb2.config(bg="SkyBlue2")
    tb3.config(bg="SkyBlue2")
    tb4.config(bg="SkyBlue2")
    tb5.config(bg="SkyBlue2")
    tb6.config(bg="SkyBlue2")
    tb7.config(bg="SkyBlue2")
    tb8.config(bg="SkyBlue2")
    tb9.config(bg="SkyBlue2")
    tb10.config(bg="SkyBlue2")
    
    
def clear():
    
    entry.delete(0,END)
    la.grid_forget()
    lb.grid_forget()
    lc.grid_forget()
    ld.grid_forget()
    le.grid_forget()
    lf.grid_forget()
    lg.grid_forget()
    l1.grid_forget()
    l2.grid_forget()
    l3.grid_forget()
    l4.grid_forget()
    l5.grid_forget()
    l6.grid_forget()
    l7.grid_forget()
    l8.grid_forget()
    l9.grid_forget()
    l10.grid_forget()
    m1.grid_forget()
    m2.grid_forget()
    m3.grid_forget()
    m4.grid_forget()
    m5.grid_forget()
    m6.grid_forget()
    m7.grid_forget()
    m8.grid_forget()
    m9.grid_forget()
    m10.grid_forget()
    ib1.grid_forget()
    ib2.grid_forget()
    ib3.grid_forget()
    ib4.grid_forget()
    ib5.grid_forget()
    ib6.grid_forget()
    ib7.grid_forget()
    ib8.grid_forget()
    ib9.grid_forget()
    ib10.grid_forget()
    tb1.grid_forget()
    tb2.grid_forget()
    tb3.grid_forget()
    tb4.grid_forget()
    tb5.grid_forget()
    tb6.grid_forget()
    tb7.grid_forget()
    tb8.grid_forget()
    tb9.grid_forget()
    tb10.grid_forget()
    
    btni.place_forget()
    btnt.place_forget()
    
    
btn1 = Button(master, text="Recommend", bg="green4",fg="white", font = ('Times',12), command=recommend)
btn1.place(x=690, y=140)
    
btn2 = Button(master, text="Clear", bg="red4", fg="white", font = ('Times',12), command=clear)
btn2.place(x=710, y=180)

master.mainloop()
